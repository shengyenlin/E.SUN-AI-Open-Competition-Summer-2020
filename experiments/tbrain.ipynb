# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import random
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/Users/linyuxiang/tbrain/rf.df.csv')

# %%
random.seed(123)

# %%
np.random.choice([1,2],p = [0.8,0.2],)

# %%
train_df, test_df = train_test_split(df,test_size = 0.2)

# %%
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')

# %%
a = list(train_df.columns)
a.remove('name')
a.remove('news_ID')
a.remove('name_id')
a.remove('y')

# %%
model.fit(train_df[a], train_df['y'])

# %%
predictions = model.predict(test_df[a])

# %%
accuracy = metrics.accuracy_score(test_df['y'], predictions)
pd.concat([test_df[['name','news_ID','y']],pd.DataFrame(predictions)],axis = 1,ignore_index= True)

# %%
ans = pd.concat([a,pd.DataFrame(predictions).rename(columns = {'0': 'guess'})],axis = 1)

# %%
ans_table = ans.groupby(['name','news_ID']).sum()
ans_table = ans_table.rename(columns = {0:'guess'})

# %%
ans_table['y'][ans_table['y']>1] = 1
ans_table['guess'][ans_table['guess']>1] = 1

# %%
accuracy = metrics.accuracy_score(ans_table['y'], ans_table['guess'])
f1 = metrics.f1_score(ans_table['y'], ans_table['guess'])

# %%
accuracy

# %%
f1

# %%
df = ckip_output

# %%
df[df['word_pos']=="PERSON"]

# %%
keyword = pd.read_csv('https://raw.githubusercontent.com/YuSiangLin/Tbrain/master/keyword.csv')
